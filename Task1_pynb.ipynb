# %% [markdown]
# <a href="https://colab.research.google.com/github/hello-muhammad-hamza/Task1/blob/main/Task1_pynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Task 1 ( Topic String )

# %%
print("Hello World")
variable = "Starting with the supreme name of almighty Allaha.\nHe is the most merciful and kind." # backslash use for line breaking(\n).
print(variable)
print(len(variable)) #(len) This symbol is used to find the length of string.
print(variable[0])   #[] This symbol is used for index of any string (to locate specific location of any letter or nuber)
print(variable[0:5]) #[x:y] In this way you can find any starting and ending index of string.

# Find the upper , lower , count , find , replace ,
variable2 = "Welcome"
print(variable2.upper())
print(variable2.lower())
print(variable2.count("e"))
print(variable2.find("m"))
print(variable2.replace('Welcome','Invitation'))

# Combining of more than one string.
x = "Hi"
y = "Hamza"
z = x + y  # combine without space
print(z)
z2 = x +','+ y + ', Welcome!' # combine with space
print(z2)
z = f'{x},{y.upper()} Welcome!' # Here ".upper()" also use
print(z)


















































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































           )












           )
# Out:
#   File "<ipython-input-16-dfd1ba087323>", line 1035
#     )
#     ^
# IndentationError: unexpected indent
